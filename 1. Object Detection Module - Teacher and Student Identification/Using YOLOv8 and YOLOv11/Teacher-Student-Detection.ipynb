# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 904.3/904.3 kB 43.1 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip '/content/drive/My Drive/combined_dataset.zip' -d /content/combined_dataset
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/combined_dataset/combined_dataset/labels/train/23_001868.txt
#   inflating: /content/combined_dataset/combined_dataset/labels/train/23_001875.txt
#   inflating: /content/combined_dataset/combined_dataset/labels/train/23_001925.txt
#   inflating: /content/combined_dataset/combined_dataset/labels/train/23_001935.txt
#   inflating: /content/combined_dataset/combined_dataset/labels/train/23_001977.txt
#   inflating: /content/combined_dataset/combined_dataset/labels/train/23_002032.txt
#   inflating: /content/combined_dataset/combined_dataset/labels/train/23_002071.txt
#   inflating: /content/combined_dataset/combined_dataset/labels/train/23_002090.txt
#   inflating: /content/combined_dataset/combined_dataset/labels/train/23_002152.txt
#   inflating: /content/combined_dataset/combined_dataset/labels/train/23_002200.txt
#   inflating: /content/combined_dataset/combined_dataset/labels/train/23_002223.txt
# ...

# %%
with open('dataset.yaml', 'w') as f:
    f.write("""
    train: /content/combined_dataset/combined_dataset/images/train
    val: /content/combined_dataset/combined_dataset/images/val

    nc: 2
    names: ['teacher', 'student']
    """)

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=dataset.yaml epochs=50 batch=16 imgsz=640
# Out:
# Ultralytics 8.3.55 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from google.colab import files
files.download('/content/runs/detect/train2/weights/best.pt')

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train2/weights/best.pt source=/content/drive/My\ Drive/Exam\ Footages show_conf=False
# !yolo task=detect mode=predict model=/content/runs/detect/train2/weights/best.pt source=/content/drive/My\ Drive/Exam\ Footages/Exam_Footage_Sample_1.mp4 show_conf=False
# Out:
# /bin/bash: line 1: yolo: command not found
